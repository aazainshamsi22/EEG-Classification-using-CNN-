# %% [markdown]
# ##Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Import Libraries

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import scipy
from scipy import signal

import os
import keras
import tensorflow as tf

from keras.models import Model
from tensorflow.keras import layers
from keras import layers

import numpy as np
from keras import backend as K
from keras.utils import np_utils

import math
from keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam
from keras import regularizers
from keras.callbacks import LearningRateScheduler
from tensorflow.keras.constraints import max_norm

# %%
initializer = tf.keras.initializers.HeNormal()
bias_init = keras.initializers.Constant(value=0.2)

# %% [markdown]
# ##Load Some Datafiles

# %%
t = np.load('/content/drive/MyDrive/IndividualData/A01T_X.npy')
e = np.load('/content/drive/MyDrive/IndividualData/A01E_X.npy')
ty = np.load('/content/drive/MyDrive/IndividualData/A01T_Y.npy')
ey = np.load('/content/drive/MyDrive/IndividualData/A01E_Y.npy')

# %%
# Print the array
print(t)
# Out:
# [[[ -5.71289062  -6.88476562  -3.80859375 ...   6.640625     9.27734375
#      8.49609375]
#   [ -2.97851562  -2.68554688  -1.26953125 ...   3.46679688   2.39257812
#      3.22265625]
#   [ -5.61523438  -7.76367188  -5.37109375 ...   4.44335938   7.27539062
#      5.95703125]
#   ...
#   [  0.09765625  -0.92773438  -1.46484375 ...   7.27539062   8.83789062
#      4.00390625]
#   [ -1.5625      -3.22265625  -3.66210938 ...   4.05273438   6.15234375
#      2.1484375 ]
#   [ -0.14648438  -3.46679688  -4.34570312 ...   7.08007812   7.76367188
#      0.5859375 ]]
#
#  [[-11.328125   -11.27929688  -7.8125     ...   2.88085938   1.61132812
#     11.57226562]
#   [-11.86523438 -12.06054688 -13.8671875  ...   1.5625       3.17382812
#     10.44921875]
#   [-10.20507812 -10.88867188  -9.765625   ...   3.41796875   2.24609375
#     12.45117188]
#   ...
#   [ -5.2734375   -7.66601562  -7.2265625  ... -13.72070312 -13.18359375
#     -4.24804688]
#   [ -4.58984375  -6.49414062  -5.2734375  ... -11.71875    -12.45117188
#     -3.66210938]
#   [ -6.68945312 -10.00976562  -9.9609375  ... -20.36132812 -19.18945312
#     -9.03320312]]
#
#  [[ 12.98828125   9.81445312   1.70898438 ...   6.54296875   5.12695312
#      1.02539062]
#   [ 13.72070312  11.71875      0.1953125  ...  13.18359375  11.03515625
#      6.640625  ]
#   [ 15.08789062  10.88867188  -1.171875   ...  10.59570312   9.61914062
#      5.71289062]
#   ...
#   [  4.83398438   8.69140625   2.83203125 ...  11.23046875  11.86523438
#     10.88867188]
#   [  4.98046875  10.10742188   4.83398438 ...   9.03320312   9.13085938
#      9.42382812]
#   [  0.5859375    6.8359375    2.19726562 ...  10.00976562  10.49804688
#     11.328125  ]]
#
#  ...
#
#  [[ 15.38085938   9.22851562  11.96289062 ...  12.3046875    8.34960938
#      5.46875   ]
#   [ 12.84179688   2.734375     3.7109375  ...   5.51757812   5.90820312
#      4.00390625]
#   [ 14.11132812   5.81054688   6.78710938 ...   8.3984375    4.44335938
#      4.00390625]
#   ...
#   [ -7.66601562 -14.89257812 -10.44921875 ...   0.9765625   -0.1953125
#     -0.83007812]
#   [ -4.34570312 -11.23046875  -6.39648438 ...   1.31835938   0.34179688
#     -1.80664062]
#   [ -7.17773438 -13.96484375  -7.91015625 ...   2.44140625   0.24414062
#     -0.48828125]]
#
#  [[ -5.41992188  -4.39453125  -4.15039062 ...  -3.27148438   1.70898438
#     -6.68945312]
#   [ -6.73828125  -5.2734375   -4.39453125 ...  -4.05273438  -5.95703125
#    -10.64453125]
#   [ -5.61523438  -2.78320312  -4.1015625  ... -11.5234375   -6.25
#    -12.98828125]
#   ...
#   [  0.68359375   3.7109375    1.02539062 ... -12.54882812 -11.96289062
#    -14.0625    ]
#   [  2.83203125   4.73632812   1.953125   ... -14.55078125 -14.74609375
#    -16.30859375]
#   [  0.9765625    3.22265625   1.85546875 ... -15.52734375 -14.40429688
#    -11.76757812]]
#
#  [[ -8.984375    -5.90820312  -2.34375    ...  65.52734375  72.8515625
#     75.43945312]
#   [ -6.68945312  -0.9765625    1.12304688 ...  40.38085938  50.
#     52.24609375]
#   [ -3.27148438  -1.66015625   2.1484375  ...  38.0859375   45.06835938
#     48.19335938]
#   ...
#   [  4.19921875   9.765625     9.5703125  ...  10.00976562  20.60546875
#     22.90039062]
#   [  2.5390625    7.91015625   8.69140625 ...   9.5703125   20.26367188
#     22.16796875]
#   [  6.34765625  12.109375    11.5234375  ...   8.3984375   18.9453125
#     17.96875   ]]]

# %% [markdown]
# ##Data Analysis

# %%
# Print the shape of the array
print(t.shape)
# Out:
# (288, 22, 1875)

# %%
# Accessing the first sample, first channel, and first 10 data points
sample = t[0]
channel = t[0][0]
data_points = t[0][0][:10]

print("Sample:")
print(sample)
print("Channel:")
print(channel)
print("Data points:")
print(data_points)
# Out:
# Sample:
# [[-5.71289062 -6.88476562 -3.80859375 ...  6.640625    9.27734375
#    8.49609375]
#  [-2.97851562 -2.68554688 -1.26953125 ...  3.46679688  2.39257812
#    3.22265625]
#  [-5.61523438 -7.76367188 -5.37109375 ...  4.44335938  7.27539062
#    5.95703125]
#  ...
#  [ 0.09765625 -0.92773438 -1.46484375 ...  7.27539062  8.83789062
#    4.00390625]
#  [-1.5625     -3.22265625 -3.66210938 ...  4.05273438  6.15234375
#    2.1484375 ]
#  [-0.14648438 -3.46679688 -4.34570312 ...  7.08007812  7.76367188
#    0.5859375 ]]
# Channel:
# [-5.71289062 -6.88476562 -3.80859375 ...  6.640625    9.27734375
#   8.49609375]
# Data points:
# [ -5.71289062  -6.88476562  -3.80859375  -6.59179688   4.6875
#    1.51367188  -2.29492188  -3.61328125  -4.58984375 -10.79101562]

# %% [markdown]
# ##Plotting Insights

# %%
plt.plot(t[0][6])
plt.show()

# %%
plt.plot(e[0][7])
plt.show()

# %% [markdown]
# ##Data Pre Processing using MNE method

# %% [markdown]
# Explanation:
#
#
#
# *   The bandpass_filter() function takes in an input trials_c, which represents the trials or data that need to be filtered.
# *   It computes the shape of the input trials using np.shape().
# The sampling frequency (fs) and the lower (lowcut) and upper (highcut) cutoff frequencies for the bandpass filter are extracted.
#
#
# *   The Nyquist frequency (nyq) is computed as half of the sampling frequency.
# The filter cutoff frequencies are normalized by dividing them by the Nyquist frequency.
# *   The order parameter determines the filter order.
# An array called new_trials is initialized to store the filtered trials.
# The function applies bandpass filtering to each trial in the input data using a Butterworth filter design (signal.butter()).
#
#
#
#
# *   The filtfilt() function is used to apply zero-phase forward and reverse filtering to remove phase distortion.
# The filtered trial is stored in the new_trials array.
# *   Finally, the function returns the new_trials array containing the filtered trials. This code allows you to apply a bandpass filter to your EEG trials, ensuring that the data falls within the specified frequency range.

# %%
def bandpass_filter(trials_c, lc, hc, order = 5):
    shape = np.shape(trials_c)

    fs = float(shape[2])
    lowcut = lc
    highcut = hc

    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq

    order = order
    new_trials = np.zeros([shape[0],shape[1],shape[2]])
    for i in range(0,shape[0]):
        for j in range(0,shape[1]):
            b,a = signal.butter(order, [low,high],'bandpass', analog = False)
            y = signal.filtfilt(b, a, trials_c[i][j], axis = 0)
            new_trials[i][j] = y

    return new_trials

# %% [markdown]
# Explanation:
#
#
# *   The filter function takes a trials parameter, which represents the input trials (presumably EEG data).
# *   The function applies a bandpass filter to the trials using the bandpass_filter function.
# The first bandpass filter is applied in the frequency range of 1 to 30 Hz, and the filtered trials are stored in the variable t1to30.
#
#
# *   The second bandpass filter is applied in the frequency range of 1 to 125 Hz, and the filtered trials are stored in the variable t1to125.
# *   Finally, the function returns both sets of filtered trials, t1to30 and t1to125.
#
#
# The purpose of this code is to filter the input trials using different frequency ranges and examine the resulting shapes of the filtered data. It serves as a preprocessing step before further analysis or modeling tasks.

# %%
def filter(trials):
    t1to30 = bandpass_filter(trials,1,30, order = 2)
    print(np.shape(t1to30))
    t1to125 = bandpass_filter(trials,1,125, order = 2)
    print(np.shape(t1to125))
    return t1to30,t1to125

# %% [markdown]
# Explanation:
#
#
# *   The function data_augmentation() performs data augmentation on EEG trials.
# The subject parameter is used to specify the subject ID for which data augmentation will be performed.
# *   The EEG trials and corresponding classes are loaded from the specified file paths.
#
# *   A subset of the trials, starting from the 500th time sample and ending at the 1250th time sample, is extracted for training.
# The variables start and end are initialized to set the indices for data augmentation.
# *   A loop is used to perform data augmentation by concatenating additional trials to the training data.
#
#
# *   In each iteration of the loop, a subset of trials specified by the start and end indices is extracted for augmentation.
# *   The start and end indices are updated for the next augmentation iteration.
# The augmented trials and their corresponding classes are concatenated to the existing training data.
#
# After all augmentation iterations, the augmented training data and corresponding labels are returned.

# %%
def data_augmentation(subject = 1):
    subject = subject
    trials = np.load('/content/drive/MyDrive/IndividualData/A0' + str(subject)+'T_X.npy')
    classes = np.load('/content/drive/MyDrive/IndividualData/A0' + str(subject)+'T_Y.npy')
    x_train = trials[:,:,500:1250]
    y_train = classes
    start = 550
    end = 1300
    for i in range(1,9):
        new_trials = trials[:,:,start:end]
        start = start + 50
        end = end + 50
        x_train = np.concatenate((x_train, new_trials), axis = 0)
        y_train =  np.concatenate((y_train, classes), axis = 0)

    return x_train, y_train

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ##Classify all 4 CLASSES through Convolutional Neural Network (CNN) Model

# %% [markdown]
# ##Other Metrics: (ACCURACY, Confusion Matrix, F1 SCORE, KAPPA SCORE, PRECISION)

# %% [markdown]
# The code iterates over 9 subjects and performs the following steps for each subject:
#
# 1.   Load and preprocess the training and testing data.
# 2.   Remove unwanted classes (foot and tongue) from the training and testing data.
# Concatenate the selected classes (left hand, right hand, foot, tongue) for testing.
#
#
# 3.   Reshape the training and testing data for the input shape expected by the CNN model.
#
# 4.   Convert the labels to categorical format.
#
# 5.   Define the architecture of the CNN model.
# 6.   Compile and train the model on the training data.
#
#
# 7.   Evaluate the trained model on the testing data and print the loss and accuracy.
# 8.   Perform predictions on the testing data and calculate the confusion matrix, F-score, and Cohen's kappa score. Append the evaluation metrics to the respective lists.
#
#
# 9.   After iterating over all subjects, calculate the average confusion matrix, F-score, and kappa score.
# 10.   Print the average evaluation metrics.

# %% [markdown]
# # Optimizes the accuracies of all subjects having < 0.75

# %%
import seaborn as sns
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix, cohen_kappa_score, f1_score, precision_score
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.constraints import max_norm

# Initialize lists to store accuracy and confusion matrices
accuracies = []
confusion_matrices = []
f1_scores = []
precision_scores = []
kappa_scores = []

# Define class labels
class_labels = ['left hand', 'right hand', 'foot', 'tongue']

# Define the desired minimum average accuracy
desired_average_accuracy = 0.75

for sub in range(1, 10):
    x_train, y_train = data_augmentation(sub)
    print("Subject ID:", sub)

    x_test = np.load('/content/drive/MyDrive/IndividualData/A0' + str(sub) + 'E_X.npy')
    y_test = np.load('/content/drive/MyDrive/IndividualData/A0' + str(sub) + 'E_Y.npy')
    x_test = x_test[:, :, 500:1250]

    left_hand = np.where(y_test == 0)
    right_hand = np.where(y_test == 1)
    foot = np.where(y_test == 2)
    tongue = np.where(y_test == 3)

    x_test = np.concatenate(
        (x_test[left_hand], x_test[right_hand], x_test[foot], x_test[tongue]), axis=0
    )
    y_test = np.concatenate(
        (
            y_test[left_hand],
            y_test[right_hand],
            y_test[foot],
            y_test[tongue],
        ),
        axis=0,
    )

    left_hand_train = np.where(y_train == 0)
    right_hand_train = np.where(y_train == 1)
    foot_train = np.where(y_train == 2)
    tongue_train = np.where(y_train == 3)

    x_train = np.concatenate(
        (x_train[left_hand_train], x_train[right_hand_train], x_train[foot_train], x_train[tongue_train]), axis=0
    )
    y_train = np.concatenate(
        (
            y_train[left_hand_train],
            y_train[right_hand_train],
            y_train[foot_train],
            y_train[tongue_train],
        ),
        axis=0,
    )

    x_train = x_train.reshape((-1, 22, 750, 1))
    x_test = x_test.reshape((-1, 22, 750, 1))

    num_classes = 4

    y_train = to_categorical(y_train, num_classes)
    y_test = to_categorical(y_test, num_classes)

    input_layer = layers.Input(shape=(22, 750, 1))

    x1 = layers.Conv2D(8,(1, 25), strides=(1, 1), padding='same', activation='linear')(input_layer)
    x2 = layers.Conv2D(16,(1, 45), strides=(1, 1), padding='same', activation='linear')(input_layer)
    x3 = layers.Conv2D(32,(1, 65), strides=(1, 1), padding='same', activation='linear')(input_layer)

    x1 = layers.BatchNormalization()(x1)
    x2 = layers.BatchNormalization()(x2)
    x3 = layers.BatchNormalization()(x3)

    x1 = layers.DepthwiseConv2D(kernel_size=(22, 1),strides=(1, 1) , depth_multiplier = 2, depthwise_constraint = max_norm(1.0))(x1)
    x2 = layers.DepthwiseConv2D(kernel_size=(22, 1),strides=(1, 1) , depth_multiplier = 2, depthwise_constraint = max_norm(1.0))(x2)
    x3 = layers.DepthwiseConv2D(kernel_size=(22, 1),strides=(1, 1) , depth_multiplier = 2, depthwise_constraint = max_norm(1.0))(x3)

    x1 = layers.BatchNormalization()(x1)
    x2 = layers.BatchNormalization()(x2)
    x3 = layers.BatchNormalization()(x3)

    x1 = layers.Activation('elu')(x1)
    x2 = layers.Activation('elu')(x2)
    x3 = layers.Activation('elu')(x3)

    x1 = layers.AveragePooling2D((1, 4))(x1)
    x2 = layers.AveragePooling2D((1, 4))(x2)
    x3 = layers.AveragePooling2D((1, 4))(x3)

    x1 = layers.Dropout(0.1)(x1)
    x2 = layers.Dropout(0.2)(x2)
    x3 = layers.Dropout(0.4)(x3)

    x1 = layers.SeparableConv2D(16, (1, 16), use_bias = False, padding = 'same', activation='linear')(x1)
    x2 = layers.SeparableConv2D(16, (1, 16), use_bias = False, padding = 'same', activation='linear')(x2)
    x3 = layers.SeparableConv2D(16, (1, 16), use_bias = False, padding = 'same', activation='linear')(x3)

    x1 = layers.BatchNormalization()(x1)
    x2 = layers.BatchNormalization()(x2)
    x3 = layers.BatchNormalization()(x3)

    x1 = layers.Activation('elu')(x1)
    x2 = layers.Activation('elu')(x2)
    x3 = layers.Activation('elu')(x3)

    x1 = layers.AveragePooling2D((1, 8))(x1)
    x2 = layers.AveragePooling2D((1, 8))(x2)
    x3 = layers.AveragePooling2D((1, 8))(x3)

    x1 = layers.Dropout(0.1)(x1)
    x2 = layers.Dropout(0.2)(x2)
    x3 = layers.Dropout(0.4)(x3)

    f1 = layers.Flatten()(x1)
    f2 = layers.Flatten()(x2)
    f3 = layers.Flatten()(x3)

    c = layers.concatenate([f1,f2,f3], axis = 1)

    x = layers.Dense(num_classes, activation='softmax')(c)

    model = Model(input_layer, x, name='HS-EEGNET')
    model.summary()

    opt = Adam(learning_rate=0.001)

    epochs = 1500

    callbacks = [EarlyStopping(monitor="val_accuracy", patience=75, restore_best_weights=True)]
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

    history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=epochs,
                        batch_size=64, callbacks=callbacks)

    model.save('/content/drive/MyDrive/eeg/S0' + str(sub) + 'Model.h5')

    # Perform predictions on the test data
    y_pred = model.predict(x_test)
    y_pred_labels = np.argmax(y_pred, axis=1)
    y_true_labels = np.argmax(y_test, axis=1)

    # Calculate accuracy
    accuracy = np.mean(y_pred_labels == y_true_labels)
    accuracies.append(accuracy)

    # Calculate additional metrics
    kappa = cohen_kappa_score(y_true_labels, y_pred_labels)
    f1 = f1_score(y_true_labels, y_pred_labels, average='weighted')
    precision = precision_score(y_true_labels, y_pred_labels, average='weighted')

    # Append the metrics to the respective lists
    kappa_scores.append(kappa)
    f1_scores.append(f1)
    precision_scores.append(precision)

    # Calculate confusion matrix
    cm = confusion_matrix(y_true_labels, y_pred_labels, labels=range(num_classes))
    confusion_matrices.append(cm)

    # Print accuracy for the subject
    print("Accuracy for Subject", sub, ":", accuracy)

    # Print confusion matrix using seaborn
    print("Confusion Matrix for Subject", sub)
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()

    # Check if the current subject's accuracy is below the desired minimum
    if accuracy < desired_average_accuracy:
      # Implement the optimization strategy for the subject (e.g., increase epochs, adjust learning rate, etc.)
      print("Optimizing Subject", sub)

      # Adjust the learning rate
      opt.learning_rate.assign(0.0005)  # Set a lower learning rate

      # Increase the number of epochs
      epochs = 2000  # Increase the number of epochs

      # Compile the model with the updated optimizer
      model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

      # Train the model again with the updated parameters
      history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=epochs,
                        batch_size=16, callbacks=callbacks)

      # Perform predictions on the test data
      y_pred = model.predict(x_test)
      y_pred_labels = np.argmax(y_pred, axis=1)
      y_true_labels = np.argmax(y_test, axis=1)

      # Calculate accuracy
      accuracy = np.mean(y_pred_labels == y_true_labels)
      accuracies.append(accuracy)

      # Calculate additional metrics
      kappa = cohen_kappa_score(y_true_labels, y_pred_labels)
      f1 = f1_score(y_true_labels, y_pred_labels, average='weighted')
      precision = precision_score(y_true_labels, y_pred_labels, average='weighted')

      # Append the metrics to the respective lists
      kappa_scores.append(kappa)
      f1_scores.append(f1)
      precision_scores.append(precision)

      # Calculate confusion matrix
      cm = confusion_matrix(y_true_labels, y_pred_labels, labels=range(num_classes))
      confusion_matrices.append(cm)

      # Print accuracy for the subject after optimization
      print("Accuracy for Subject", sub, "after optimization:", accuracy)

      # Print confusion matrix using seaborn after optimization
      print("Confusion Matrix for Subject", sub, "after optimization")
      sns.heatmap(cm, annot=True, cmap='Blues', fmt='d', xticklabels=class_labels, yticklabels=class_labels)
      plt.xlabel("Predicted Labels")
      plt.ylabel("True Labels")
      plt.show()


# Calculate average accuracy
average_accuracy = np.mean(accuracies)

# Calculate other metrics
average_kappa = np.mean(kappa_scores)
average_f1 = np.mean(f1_scores)
average_precision = np.mean(precision_scores)

# Calculate average confusion matrix
average_cm = np.mean(confusion_matrices, axis=0)

# Print average confusion matrix using seaborn
print("Average Confusion Matrix:")
sns.heatmap(average_cm, annot=True, cmap='Blues', fmt='.2f', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()


# Print average accuracy
print("Average Accuracy:", average_accuracy)

# Print the other metrics
print("Average Kappa Score:", average_kappa)
print("Average F1 Score:", average_f1)
print("Average Precision:", average_precision)
# Out:
# Subject ID: 1
# Model: "HS-EEGNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 22, 750, 1)  0           []
#                                 ]
#
#  conv2d_30 (Conv2D)             (None, 22, 750, 8)   208         ['input_11[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 22, 750, 16)  736         ['input_11[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 22, 750, 32)  2112        ['input_11[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 22, 750, 8)  32          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 22, 750, 16)  64         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 22, 750, 32)  128        ['conv2d_32[0][0]']
#  ormalization)
#
#  depthwise_conv2d_30 (Depthwise  (None, 1, 750, 16)  368         ['batch_normalization_90[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_31 (Depthwise  (None, 1, 750, 32)  736         ['batch_normalization_91[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_32 (Depthwise  (None, 1, 750, 64)  1472        ['batch_normalization_92[0][0]']
#  Conv2D)
#
#  batch_normalization_93 (BatchN  (None, 1, 750, 16)  64          ['depthwise_conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_94 (BatchN  (None, 1, 750, 32)  128         ['depthwise_conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_95 (BatchN  (None, 1, 750, 64)  256         ['depthwise_conv2d_32[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 1, 750, 16)   0           ['batch_normalization_93[0][0]']
#
#  activation_61 (Activation)     (None, 1, 750, 32)   0           ['batch_normalization_94[0][0]']
#
#  activation_62 (Activation)     (None, 1, 750, 64)   0           ['batch_normalization_95[0][0]']
#
#  average_pooling2d_60 (AverageP  (None, 1, 187, 16)  0           ['activation_60[0][0]']
#  ooling2D)
#
#  average_pooling2d_61 (AverageP  (None, 1, 187, 32)  0           ['activation_61[0][0]']
#  ooling2D)
#
#  average_pooling2d_62 (AverageP  (None, 1, 187, 64)  0           ['activation_62[0][0]']
#  ooling2D)
#
#  dropout_60 (Dropout)           (None, 1, 187, 16)   0           ['average_pooling2d_60[0][0]']
#
#  dropout_61 (Dropout)           (None, 1, 187, 32)   0           ['average_pooling2d_61[0][0]']
#
#  dropout_62 (Dropout)           (None, 1, 187, 64)   0           ['average_pooling2d_62[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 1, 187, 16)  512         ['dropout_60[0][0]']
#  Conv2D)
#
#  separable_conv2d_31 (Separable  (None, 1, 187, 16)  1024        ['dropout_61[0][0]']
#  Conv2D)
#
#  separable_conv2d_32 (Separable  (None, 1, 187, 16)  2048        ['dropout_62[0][0]']
#  Conv2D)
#
#  batch_normalization_96 (BatchN  (None, 1, 187, 16)  64          ['separable_conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_97 (BatchN  (None, 1, 187, 16)  64          ['separable_conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_98 (BatchN  (None, 1, 187, 16)  64          ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  activation_63 (Activation)     (None, 1, 187, 16)   0           ['batch_normalization_96[0][0]']
#
#  activation_64 (Activation)     (None, 1, 187, 16)   0           ['batch_normalization_97[0][0]']
#
#  activation_65 (Activation)     (None, 1, 187, 16)   0           ['batch_normalization_98[0][0]']
#
#  average_pooling2d_63 (AverageP  (None, 1, 23, 16)   0           ['activation_63[0][0]']
#  ooling2D)
#
#  average_pooling2d_64 (AverageP  (None, 1, 23, 16)   0           ['activation_64[0][0]']
#  ooling2D)
#
#  average_pooling2d_65 (AverageP  (None, 1, 23, 16)   0           ['activation_65[0][0]']
#  ooling2D)
#
#  dropout_63 (Dropout)           (None, 1, 23, 16)    0           ['average_pooling2d_63[0][0]']
#
#  dropout_64 (Dropout)           (None, 1, 23, 16)    0           ['average_pooling2d_64[0][0]']
#
#  dropout_65 (Dropout)           (None, 1, 23, 16)    0           ['average_pooling2d_65[0][0]']
#
#  flatten_30 (Flatten)           (None, 368)          0           ['dropout_63[0][0]']
#
#  flatten_31 (Flatten)           (None, 368)          0           ['dropout_64[0][0]']
#
#  flatten_32 (Flatten)           (None, 368)          0           ['dropout_65[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 1104)         0           ['flatten_30[0][0]',
#                                                                   'flatten_31[0][0]',
#                                                                   'flatten_32[0][0]']
#
#  dense_10 (Dense)               (None, 4)            4420        ['concatenate_10[0][0]']
#
# ==================================================================================================
# Total params: 14,500
# Trainable params: 14,068
# Non-trainable params: 432
# __________________________________________________________________________________________________
# Epoch 1/1500
# 41/41 [==============================] - 16s 91ms/step - loss: 1.4384 - accuracy: 0.3110 - val_loss: 1.3591 - val_accuracy: 0.3438
# Epoch 2/1500
# 41/41 [==============================] - 3s 77ms/step - loss: 1.0159 - accuracy: 0.5177 - val_loss: 1.3639 - val_accuracy: 0.2917
# Epoch 3/1500
# 41/41 [==============================] - 4s 89ms/step - loss: 0.8027 - accuracy: 0.6165 - val_loss: 1.8396 - val_accuracy: 0.2847
# Epoch 4/1500
# 41/41 [==============================] - 3s 78ms/step - loss: 0.6928 - accuracy: 0.6944 - val_loss: 2.3012 - val_accuracy: 0.2917
# Epoch 5/1500
# 41/41 [==============================] - 3s 78ms/step - loss: 0.6111 - accuracy: 0.7365 - val_loss: 2.5931 - val_accuracy: 0.3264
# Epoch 6/1500
# 41/41 [==============================] - 3s 80ms/step - loss: 0.5480 - accuracy: 0.7681 - val_loss: 2.5999 - val_accuracy: 0.3889
# Epoch 7/1500
# 41/41 [==============================] - 3s 78ms/step - loss: 0.5154 - accuracy: 0.7812 - val_loss: 2.3277 - val_accuracy: 0.3438
# Epoch 8/1500
# 41/41 [==============================] - 3s 76ms/step - loss: 0.4674 - accuracy: 0.8036 - val_loss: 2.0900 - val_accuracy: 0.4410
# Epoch 9/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.4304 - accuracy: 0.8187 - val_loss: 1.5986 - val_accuracy: 0.4757
# Epoch 10/1500
# 41/41 [==============================] - 3s 79ms/step - loss: 0.4061 - accuracy: 0.8329 - val_loss: 1.3440 - val_accuracy: 0.5590
# Epoch 11/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.3869 - accuracy: 0.8434 - val_loss: 1.0323 - val_accuracy: 0.6562
# Epoch 12/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.3562 - accuracy: 0.8630 - val_loss: 0.7207 - val_accuracy: 0.7118
# Epoch 13/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.3236 - accuracy: 0.8773 - val_loss: 0.6673 - val_accuracy: 0.7361
# Epoch 14/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.3110 - accuracy: 0.8765 - val_loss: 0.7711 - val_accuracy: 0.7118
# Epoch 15/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.2835 - accuracy: 0.8916 - val_loss: 0.6162 - val_accuracy: 0.7708
# Epoch 16/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.2764 - accuracy: 0.8970 - val_loss: 0.6264 - val_accuracy: 0.7569
# Epoch 17/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.2336 - accuracy: 0.9163 - val_loss: 0.6547 - val_accuracy: 0.7604
# Epoch 18/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2434 - accuracy: 0.9062 - val_loss: 0.8091 - val_accuracy: 0.7188
# Epoch 19/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.2351 - accuracy: 0.9147 - val_loss: 0.9416 - val_accuracy: 0.6736
# Epoch 20/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.2268 - accuracy: 0.9140 - val_loss: 0.8342 - val_accuracy: 0.6806
# Epoch 21/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2004 - accuracy: 0.9209 - val_loss: 0.6976 - val_accuracy: 0.7361
# Epoch 22/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1814 - accuracy: 0.9356 - val_loss: 0.6926 - val_accuracy: 0.7500
# Epoch 23/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1812 - accuracy: 0.9340 - val_loss: 0.6458 - val_accuracy: 0.7708
# Epoch 24/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1604 - accuracy: 0.9406 - val_loss: 0.6124 - val_accuracy: 0.7882
# Epoch 25/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1644 - accuracy: 0.9433 - val_loss: 0.6597 - val_accuracy: 0.7882
# Epoch 26/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1555 - accuracy: 0.9502 - val_loss: 0.6448 - val_accuracy: 0.7882
# Epoch 27/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1493 - accuracy: 0.9452 - val_loss: 0.6443 - val_accuracy: 0.7847
# Epoch 28/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1310 - accuracy: 0.9533 - val_loss: 0.6579 - val_accuracy: 0.7812
# Epoch 29/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1286 - accuracy: 0.9537 - val_loss: 0.8258 - val_accuracy: 0.7361
# Epoch 30/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1292 - accuracy: 0.9549 - val_loss: 0.6597 - val_accuracy: 0.7639
# Epoch 31/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1189 - accuracy: 0.9587 - val_loss: 0.6546 - val_accuracy: 0.7778
# Epoch 32/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1019 - accuracy: 0.9649 - val_loss: 0.9189 - val_accuracy: 0.7292
# Epoch 33/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1106 - accuracy: 0.9626 - val_loss: 0.7175 - val_accuracy: 0.7500
# Epoch 34/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1024 - accuracy: 0.9660 - val_loss: 1.2546 - val_accuracy: 0.6736
# Epoch 35/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0938 - accuracy: 0.9660 - val_loss: 0.7068 - val_accuracy: 0.7708
# Epoch 36/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1104 - accuracy: 0.9622 - val_loss: 0.9271 - val_accuracy: 0.7292
# Epoch 37/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0968 - accuracy: 0.9637 - val_loss: 0.7244 - val_accuracy: 0.7674
# Epoch 38/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0928 - accuracy: 0.9680 - val_loss: 0.8003 - val_accuracy: 0.7708
# Epoch 39/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0822 - accuracy: 0.9726 - val_loss: 0.7054 - val_accuracy: 0.8021
# Epoch 40/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0766 - accuracy: 0.9772 - val_loss: 0.7566 - val_accuracy: 0.7882
# Epoch 41/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0775 - accuracy: 0.9742 - val_loss: 0.9477 - val_accuracy: 0.7361
# Epoch 42/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0890 - accuracy: 0.9660 - val_loss: 0.8727 - val_accuracy: 0.7708
# Epoch 43/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0760 - accuracy: 0.9749 - val_loss: 0.7760 - val_accuracy: 0.7847
# Epoch 44/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0810 - accuracy: 0.9722 - val_loss: 0.6841 - val_accuracy: 0.7917
# Epoch 45/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0756 - accuracy: 0.9730 - val_loss: 1.0184 - val_accuracy: 0.7396
# Epoch 46/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0715 - accuracy: 0.9765 - val_loss: 0.7998 - val_accuracy: 0.7812
# Epoch 47/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0610 - accuracy: 0.9826 - val_loss: 0.7530 - val_accuracy: 0.8090
# Epoch 48/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0657 - accuracy: 0.9780 - val_loss: 0.9095 - val_accuracy: 0.7604
# Epoch 49/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0753 - accuracy: 0.9757 - val_loss: 1.0729 - val_accuracy: 0.7396
# Epoch 50/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0729 - accuracy: 0.9761 - val_loss: 0.6769 - val_accuracy: 0.8021
# Epoch 51/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0664 - accuracy: 0.9788 - val_loss: 0.8535 - val_accuracy: 0.7604
# Epoch 52/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0647 - accuracy: 0.9796 - val_loss: 0.6963 - val_accuracy: 0.7882
# Epoch 53/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0669 - accuracy: 0.9780 - val_loss: 0.8810 - val_accuracy: 0.7812
# Epoch 54/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0623 - accuracy: 0.9780 - val_loss: 0.9328 - val_accuracy: 0.7292
# Epoch 55/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0578 - accuracy: 0.9830 - val_loss: 0.7802 - val_accuracy: 0.7917
# Epoch 56/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0619 - accuracy: 0.9803 - val_loss: 0.8964 - val_accuracy: 0.7535
# Epoch 57/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0478 - accuracy: 0.9830 - val_loss: 1.0102 - val_accuracy: 0.7396
# Epoch 58/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0581 - accuracy: 0.9803 - val_loss: 0.7209 - val_accuracy: 0.8021
# Epoch 59/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0648 - accuracy: 0.9772 - val_loss: 0.7688 - val_accuracy: 0.7917
# Epoch 60/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0445 - accuracy: 0.9857 - val_loss: 0.8109 - val_accuracy: 0.7743
# Epoch 61/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0654 - accuracy: 0.9753 - val_loss: 0.8422 - val_accuracy: 0.7986
# Epoch 62/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0551 - accuracy: 0.9811 - val_loss: 0.8185 - val_accuracy: 0.7812
# Epoch 63/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0554 - accuracy: 0.9811 - val_loss: 0.7143 - val_accuracy: 0.8056
# Epoch 64/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0511 - accuracy: 0.9826 - val_loss: 0.6716 - val_accuracy: 0.8021
# Epoch 65/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0532 - accuracy: 0.9815 - val_loss: 0.8999 - val_accuracy: 0.7812
# Epoch 66/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0485 - accuracy: 0.9846 - val_loss: 0.7767 - val_accuracy: 0.7778
# Epoch 67/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0362 - accuracy: 0.9904 - val_loss: 0.8421 - val_accuracy: 0.7778
# Epoch 68/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0464 - accuracy: 0.9834 - val_loss: 0.8796 - val_accuracy: 0.7882
# Epoch 69/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0435 - accuracy: 0.9861 - val_loss: 0.8196 - val_accuracy: 0.7882
# Epoch 70/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0347 - accuracy: 0.9911 - val_loss: 0.8700 - val_accuracy: 0.7882
# Epoch 71/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0422 - accuracy: 0.9853 - val_loss: 0.8675 - val_accuracy: 0.7674
# Epoch 72/1500
# 41/41 [==============================] - 3s 76ms/step - loss: 0.0429 - accuracy: 0.9846 - val_loss: 0.8523 - val_accuracy: 0.7708
# Epoch 73/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0401 - accuracy: 0.9880 - val_loss: 0.8526 - val_accuracy: 0.7604
# Epoch 74/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0373 - accuracy: 0.9865 - val_loss: 1.0103 - val_accuracy: 0.7604
# Epoch 75/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0432 - accuracy: 0.9846 - val_loss: 0.8696 - val_accuracy: 0.7778
# Epoch 76/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0508 - accuracy: 0.9838 - val_loss: 1.1126 - val_accuracy: 0.7535
# Epoch 77/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0437 - accuracy: 0.9865 - val_loss: 0.9174 - val_accuracy: 0.7882
# Epoch 78/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0396 - accuracy: 0.9861 - val_loss: 0.8592 - val_accuracy: 0.7778
# Epoch 79/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0399 - accuracy: 0.9877 - val_loss: 0.9735 - val_accuracy: 0.7639
# Epoch 80/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0314 - accuracy: 0.9873 - val_loss: 0.7628 - val_accuracy: 0.8056
# Epoch 81/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0268 - accuracy: 0.9907 - val_loss: 0.7872 - val_accuracy: 0.8021
# Epoch 82/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0429 - accuracy: 0.9869 - val_loss: 0.8526 - val_accuracy: 0.7847
# Epoch 83/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0351 - accuracy: 0.9873 - val_loss: 1.5030 - val_accuracy: 0.6875
# Epoch 84/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0413 - accuracy: 0.9857 - val_loss: 1.0749 - val_accuracy: 0.7778
# Epoch 85/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0452 - accuracy: 0.9853 - val_loss: 0.8103 - val_accuracy: 0.8021
# Epoch 86/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0448 - accuracy: 0.9842 - val_loss: 0.9924 - val_accuracy: 0.7500
# Epoch 87/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0407 - accuracy: 0.9838 - val_loss: 1.2731 - val_accuracy: 0.7292
# Epoch 88/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0329 - accuracy: 0.9907 - val_loss: 0.9350 - val_accuracy: 0.7812
# Epoch 89/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0395 - accuracy: 0.9853 - val_loss: 1.0786 - val_accuracy: 0.7396
# Epoch 90/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0412 - accuracy: 0.9877 - val_loss: 1.3769 - val_accuracy: 0.7292
# Epoch 91/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0487 - accuracy: 0.9823 - val_loss: 0.9150 - val_accuracy: 0.7882
# Epoch 92/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0271 - accuracy: 0.9904 - val_loss: 0.9339 - val_accuracy: 0.7708
# Epoch 93/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.9781 - val_accuracy: 0.7569
# Epoch 94/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0305 - accuracy: 0.9861 - val_loss: 1.1109 - val_accuracy: 0.7500
# Epoch 95/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0379 - accuracy: 0.9861 - val_loss: 1.0990 - val_accuracy: 0.7708
# Epoch 96/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0335 - accuracy: 0.9873 - val_loss: 1.0478 - val_accuracy: 0.7812
# Epoch 97/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0385 - accuracy: 0.9877 - val_loss: 1.0516 - val_accuracy: 0.7708
# Epoch 98/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0382 - accuracy: 0.9846 - val_loss: 1.0335 - val_accuracy: 0.7569
# Epoch 99/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0353 - accuracy: 0.9869 - val_loss: 0.8883 - val_accuracy: 0.7917
# Epoch 100/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0306 - accuracy: 0.9884 - val_loss: 1.0414 - val_accuracy: 0.7812
# Epoch 101/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0264 - accuracy: 0.9904 - val_loss: 0.8440 - val_accuracy: 0.7917
# Epoch 102/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0317 - accuracy: 0.9892 - val_loss: 1.2569 - val_accuracy: 0.7708
# Epoch 103/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0293 - accuracy: 0.9892 - val_loss: 0.8985 - val_accuracy: 0.7951
# Epoch 104/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0242 - accuracy: 0.9915 - val_loss: 0.8336 - val_accuracy: 0.7882
# Epoch 105/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0202 - accuracy: 0.9942 - val_loss: 0.8517 - val_accuracy: 0.8021
# Epoch 106/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.9500 - val_accuracy: 0.7812
# Epoch 107/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0412 - accuracy: 0.9846 - val_loss: 1.0791 - val_accuracy: 0.7639
# Epoch 108/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.9941 - val_accuracy: 0.8056
# Epoch 109/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0301 - accuracy: 0.9896 - val_loss: 0.7764 - val_accuracy: 0.7951
# Epoch 110/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0329 - accuracy: 0.9888 - val_loss: 2.0647 - val_accuracy: 0.6701
# Epoch 111/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0229 - accuracy: 0.9938 - val_loss: 0.7871 - val_accuracy: 0.8090
# Epoch 112/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0223 - accuracy: 0.9931 - val_loss: 1.0377 - val_accuracy: 0.7639
# Epoch 113/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.9747 - val_accuracy: 0.7708
# Epoch 114/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0462 - accuracy: 0.9823 - val_loss: 1.2287 - val_accuracy: 0.7778
# Epoch 115/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0329 - accuracy: 0.9865 - val_loss: 0.7577 - val_accuracy: 0.7917
# Epoch 116/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0236 - accuracy: 0.9942 - val_loss: 0.7593 - val_accuracy: 0.7778
# Epoch 117/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0280 - accuracy: 0.9904 - val_loss: 0.8472 - val_accuracy: 0.7951
# Epoch 118/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0251 - accuracy: 0.9900 - val_loss: 0.9846 - val_accuracy: 0.7778
# Epoch 119/1500
# 41/41 [==============================] - 3s 79ms/step - loss: 0.0236 - accuracy: 0.9923 - val_loss: 0.7766 - val_accuracy: 0.8125
# Epoch 120/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0236 - accuracy: 0.9900 - val_loss: 1.2950 - val_accuracy: 0.7500
# Epoch 121/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0362 - accuracy: 0.9865 - val_loss: 0.9798 - val_accuracy: 0.7604
# Epoch 122/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0236 - accuracy: 0.9927 - val_loss: 1.3348 - val_accuracy: 0.7465
# Epoch 123/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 1.1035 - val_accuracy: 0.8056
# Epoch 124/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0275 - accuracy: 0.9892 - val_loss: 1.0242 - val_accuracy: 0.7951
# Epoch 125/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0283 - accuracy: 0.9904 - val_loss: 0.8864 - val_accuracy: 0.7951
# Epoch 126/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0266 - accuracy: 0.9900 - val_loss: 1.1295 - val_accuracy: 0.7743
# Epoch 127/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0239 - accuracy: 0.9904 - val_loss: 1.2197 - val_accuracy: 0.7778
# Epoch 128/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0240 - accuracy: 0.9904 - val_loss: 0.8026 - val_accuracy: 0.7882
# Epoch 129/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0276 - accuracy: 0.9919 - val_loss: 1.1501 - val_accuracy: 0.7569
# Epoch 130/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0195 - accuracy: 0.9931 - val_loss: 1.4392 - val_accuracy: 0.7118
# Epoch 131/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0196 - accuracy: 0.9915 - val_loss: 1.0414 - val_accuracy: 0.7674
# Epoch 132/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0353 - accuracy: 0.9888 - val_loss: 0.9856 - val_accuracy: 0.7847
# Epoch 133/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0250 - accuracy: 0.9927 - val_loss: 0.9722 - val_accuracy: 0.7917
# Epoch 134/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0268 - accuracy: 0.9923 - val_loss: 0.8895 - val_accuracy: 0.7847
# Epoch 135/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0192 - accuracy: 0.9919 - val_loss: 0.9322 - val_accuracy: 0.7778
# Epoch 136/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0222 - accuracy: 0.9919 - val_loss: 0.8995 - val_accuracy: 0.7708
# Epoch 137/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0178 - accuracy: 0.9927 - val_loss: 0.8654 - val_accuracy: 0.8090
# Epoch 138/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0167 - accuracy: 0.9946 - val_loss: 0.8293 - val_accuracy: 0.8125
# Epoch 139/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0219 - accuracy: 0.9934 - val_loss: 1.0413 - val_accuracy: 0.7986
# Epoch 140/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0233 - accuracy: 0.9915 - val_loss: 1.2149 - val_accuracy: 0.7639
# Epoch 141/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0262 - accuracy: 0.9911 - val_loss: 1.3547 - val_accuracy: 0.7500
# Epoch 142/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0244 - accuracy: 0.9931 - val_loss: 1.0713 - val_accuracy: 0.7674
# Epoch 143/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0293 - accuracy: 0.9900 - val_loss: 0.9790 - val_accuracy: 0.7917
# Epoch 144/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0237 - accuracy: 0.9931 - val_loss: 1.2728 - val_accuracy: 0.7639
# Epoch 145/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0214 - accuracy: 0.9915 - val_loss: 1.2519 - val_accuracy: 0.7604
# Epoch 146/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0144 - accuracy: 0.9950 - val_loss: 1.3601 - val_accuracy: 0.7639
# Epoch 147/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0145 - accuracy: 0.9961 - val_loss: 0.8918 - val_accuracy: 0.8090
# Epoch 148/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0116 - accuracy: 0.9969 - val_loss: 0.8840 - val_accuracy: 0.7882
# Epoch 149/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0201 - accuracy: 0.9934 - val_loss: 1.1331 - val_accuracy: 0.7674
# Epoch 150/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0327 - accuracy: 0.9896 - val_loss: 1.4330 - val_accuracy: 0.7222
# Epoch 151/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0396 - accuracy: 0.9842 - val_loss: 1.3497 - val_accuracy: 0.7674
# Epoch 152/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0276 - accuracy: 0.9896 - val_loss: 0.9465 - val_accuracy: 0.7917
# Epoch 153/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0289 - accuracy: 0.9884 - val_loss: 0.9885 - val_accuracy: 0.7812
# Epoch 154/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0235 - accuracy: 0.9923 - val_loss: 1.0211 - val_accuracy: 0.7708
# Epoch 155/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0199 - accuracy: 0.9938 - val_loss: 1.0108 - val_accuracy: 0.7986
# Epoch 156/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.8779 - val_accuracy: 0.7847
# Epoch 157/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0235 - accuracy: 0.9907 - val_loss: 1.0584 - val_accuracy: 0.7743
# Epoch 158/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0188 - accuracy: 0.9946 - val_loss: 1.0985 - val_accuracy: 0.7674
# Epoch 159/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0239 - accuracy: 0.9911 - val_loss: 2.4344 - val_accuracy: 0.6736
# Epoch 160/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0332 - accuracy: 0.9888 - val_loss: 1.1024 - val_accuracy: 0.7882
# Epoch 161/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0258 - accuracy: 0.9923 - val_loss: 1.0261 - val_accuracy: 0.7708
# Epoch 162/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0208 - accuracy: 0.9938 - val_loss: 1.1302 - val_accuracy: 0.7743
# Epoch 163/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0264 - accuracy: 0.9904 - val_loss: 1.0534 - val_accuracy: 0.7743
# Epoch 164/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0325 - accuracy: 0.9896 - val_loss: 0.8686 - val_accuracy: 0.8125
# Epoch 165/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0199 - accuracy: 0.9946 - val_loss: 1.3156 - val_accuracy: 0.7569
# Epoch 166/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0181 - accuracy: 0.9931 - val_loss: 0.9022 - val_accuracy: 0.7743
# Epoch 167/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0177 - accuracy: 0.9927 - val_loss: 0.8653 - val_accuracy: 0.7986
# Epoch 168/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 0.9456 - val_accuracy: 0.7882
# Epoch 169/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0213 - accuracy: 0.9934 - val_loss: 1.0896 - val_accuracy: 0.7917
# Epoch 170/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0162 - accuracy: 0.9958 - val_loss: 1.0000 - val_accuracy: 0.7882
# Epoch 171/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0151 - accuracy: 0.9950 - val_loss: 1.1745 - val_accuracy: 0.7604
# Epoch 172/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0104 - accuracy: 0.9969 - val_loss: 1.0707 - val_accuracy: 0.7812
# Epoch 173/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0132 - accuracy: 0.9961 - val_loss: 0.9688 - val_accuracy: 0.7882
# Epoch 174/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0121 - accuracy: 0.9954 - val_loss: 0.8961 - val_accuracy: 0.8021
# Epoch 175/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0130 - accuracy: 0.9954 - val_loss: 1.1600 - val_accuracy: 0.7674
# Epoch 176/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0281 - accuracy: 0.9911 - val_loss: 1.3148 - val_accuracy: 0.7604
# Epoch 177/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0225 - accuracy: 0.9919 - val_loss: 0.9382 - val_accuracy: 0.8021
# Epoch 178/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0259 - accuracy: 0.9907 - val_loss: 1.0754 - val_accuracy: 0.7847
# Epoch 179/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.8724 - val_accuracy: 0.7812
# Epoch 180/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0231 - accuracy: 0.9892 - val_loss: 1.1796 - val_accuracy: 0.7500
# Epoch 181/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 1.3434 - val_accuracy: 0.7500
# Epoch 182/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0140 - accuracy: 0.9950 - val_loss: 1.5990 - val_accuracy: 0.7188
# Epoch 183/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0248 - accuracy: 0.9907 - val_loss: 1.2493 - val_accuracy: 0.7847
# Epoch 184/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 1.0150 - val_accuracy: 0.7778
# Epoch 185/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0156 - accuracy: 0.9938 - val_loss: 0.9992 - val_accuracy: 0.8056
# Epoch 186/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0173 - accuracy: 0.9965 - val_loss: 0.9505 - val_accuracy: 0.8021
# Epoch 187/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0361 - accuracy: 0.9892 - val_loss: 1.7336 - val_accuracy: 0.7500
# Epoch 188/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 0.9815 - val_accuracy: 0.7500
# Epoch 189/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0207 - accuracy: 0.9923 - val_loss: 1.4030 - val_accuracy: 0.7639
# Epoch 190/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 1.4302 - val_accuracy: 0.7257
# Epoch 191/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 1.3534 - val_accuracy: 0.7153
# Epoch 192/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0174 - accuracy: 0.9931 - val_loss: 1.3311 - val_accuracy: 0.7465
# Epoch 193/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0300 - accuracy: 0.9904 - val_loss: 0.8408 - val_accuracy: 0.7986
# Epoch 194/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0159 - accuracy: 0.9934 - val_loss: 1.1021 - val_accuracy: 0.7778
# 9/9 [==============================] - 0s 10ms/step
# Accuracy for Subject 1 : 0.8125
# Confusion Matrix for Subject 1
# Subject ID: 2
# Model: "HS-EEGNET"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 22, 750, 1)  0           []
#                                 ]
#
#  conv2d_33 (Conv2D)             (None, 22, 750, 8)   208         ['input_12[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 22, 750, 16)  736         ['input_12[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 22, 750, 32)  2112        ['input_12[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 22, 750, 8)  32          ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_100 (Batch  (None, 22, 750, 16)  64         ['conv2d_34[0][0]']
#  Normalization)
#
#  batch_normalization_101 (Batch  (None, 22, 750, 32)  128        ['conv2d_35[0][0]']
#  Normalization)
#
#  depthwise_conv2d_33 (Depthwise  (None, 1, 750, 16)  368         ['batch_normalization_99[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_34 (Depthwise  (None, 1, 750, 32)  736         ['batch_normalization_100[0][0]']
#  Conv2D)
#
#  depthwise_conv2d_35 (Depthwise  (None, 1, 750, 64)  1472        ['batch_normalization_101[0][0]']
#  Conv2D)
#
#  batch_normalization_102 (Batch  (None, 1, 750, 16)  64          ['depthwise_conv2d_33[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 1, 750, 32)  128         ['depthwise_conv2d_34[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 1, 750, 64)  256         ['depthwise_conv2d_35[0][0]']
#  Normalization)
#
#  activation_66 (Activation)     (None, 1, 750, 16)   0           ['batch_normalization_102[0][0]']
#
#  activation_67 (Activation)     (None, 1, 750, 32)   0           ['batch_normalization_103[0][0]']
#
#  activation_68 (Activation)     (None, 1, 750, 64)   0           ['batch_normalization_104[0][0]']
#
#  average_pooling2d_66 (AverageP  (None, 1, 187, 16)  0           ['activation_66[0][0]']
#  ooling2D)
#
#  average_pooling2d_67 (AverageP  (None, 1, 187, 32)  0           ['activation_67[0][0]']
#  ooling2D)
#
#  average_pooling2d_68 (AverageP  (None, 1, 187, 64)  0           ['activation_68[0][0]']
#  ooling2D)
#
#  dropout_66 (Dropout)           (None, 1, 187, 16)   0           ['average_pooling2d_66[0][0]']
#
#  dropout_67 (Dropout)           (None, 1, 187, 32)   0           ['average_pooling2d_67[0][0]']
#
#  dropout_68 (Dropout)           (None, 1, 187, 64)   0           ['average_pooling2d_68[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 1, 187, 16)  512         ['dropout_66[0][0]']
#  Conv2D)
#
#  separable_conv2d_34 (Separable  (None, 1, 187, 16)  1024        ['dropout_67[0][0]']
#  Conv2D)
#
#  separable_conv2d_35 (Separable  (None, 1, 187, 16)  2048        ['dropout_68[0][0]']
#  Conv2D)
#
#  batch_normalization_105 (Batch  (None, 1, 187, 16)  64          ['separable_conv2d_33[0][0]']
#  Normalization)
#
#  batch_normalization_106 (Batch  (None, 1, 187, 16)  64          ['separable_conv2d_34[0][0]']
#  Normalization)
#
#  batch_normalization_107 (Batch  (None, 1, 187, 16)  64          ['separable_conv2d_35[0][0]']
#  Normalization)
#
#  activation_69 (Activation)     (None, 1, 187, 16)   0           ['batch_normalization_105[0][0]']
#
#  activation_70 (Activation)     (None, 1, 187, 16)   0           ['batch_normalization_106[0][0]']
#
#  activation_71 (Activation)     (None, 1, 187, 16)   0           ['batch_normalization_107[0][0]']
#
#  average_pooling2d_69 (AverageP  (None, 1, 23, 16)   0           ['activation_69[0][0]']
#  ooling2D)
# ...
# Epoch 13/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.7047 - accuracy: 0.7245 - val_loss: 2.1212 - val_accuracy: 0.3785
# Epoch 14/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.6695 - accuracy: 0.7427 - val_loss: 2.0532 - val_accuracy: 0.3715
# Epoch 15/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.6378 - accuracy: 0.7627 - val_loss: 2.1189 - val_accuracy: 0.3368
# Epoch 16/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.6188 - accuracy: 0.7527 - val_loss: 1.9205 - val_accuracy: 0.3889
# Epoch 17/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.6082 - accuracy: 0.7670 - val_loss: 2.1512 - val_accuracy: 0.3715
# Epoch 18/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.5726 - accuracy: 0.7840 - val_loss: 2.0716 - val_accuracy: 0.4028
# Epoch 19/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.5636 - accuracy: 0.7897 - val_loss: 2.3250 - val_accuracy: 0.3889
# Epoch 20/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.5264 - accuracy: 0.7975 - val_loss: 2.0776 - val_accuracy: 0.4271
# Epoch 21/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.5211 - accuracy: 0.8067 - val_loss: 1.8017 - val_accuracy: 0.4410
# Epoch 22/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.5046 - accuracy: 0.8110 - val_loss: 2.3203 - val_accuracy: 0.4236
# Epoch 23/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.4742 - accuracy: 0.8268 - val_loss: 2.1401 - val_accuracy: 0.4236
# Epoch 24/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.4677 - accuracy: 0.8214 - val_loss: 2.5950 - val_accuracy: 0.4062
# Epoch 25/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.4393 - accuracy: 0.8372 - val_loss: 1.9523 - val_accuracy: 0.4653
# Epoch 26/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.4373 - accuracy: 0.8368 - val_loss: 2.7413 - val_accuracy: 0.4132
# Epoch 27/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.4197 - accuracy: 0.8349 - val_loss: 2.0968 - val_accuracy: 0.4479
# Epoch 28/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.3895 - accuracy: 0.8553 - val_loss: 2.5650 - val_accuracy: 0.4340
# Epoch 29/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.3659 - accuracy: 0.8673 - val_loss: 2.2267 - val_accuracy: 0.4618
# Epoch 30/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.3633 - accuracy: 0.8723 - val_loss: 2.5438 - val_accuracy: 0.4167
# Epoch 31/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.3458 - accuracy: 0.8708 - val_loss: 1.8358 - val_accuracy: 0.5174
# Epoch 32/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.3190 - accuracy: 0.8850 - val_loss: 2.5374 - val_accuracy: 0.4618
# Epoch 33/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.2905 - accuracy: 0.8966 - val_loss: 2.8330 - val_accuracy: 0.4132
# Epoch 34/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.2885 - accuracy: 0.8908 - val_loss: 2.2831 - val_accuracy: 0.4618
# Epoch 35/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2571 - accuracy: 0.9043 - val_loss: 2.2189 - val_accuracy: 0.4826
# Epoch 36/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2465 - accuracy: 0.9144 - val_loss: 2.6715 - val_accuracy: 0.4722
# Epoch 37/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.2484 - accuracy: 0.9035 - val_loss: 1.6767 - val_accuracy: 0.5799
# Epoch 38/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.2461 - accuracy: 0.9120 - val_loss: 1.8358 - val_accuracy: 0.5417
# Epoch 39/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2279 - accuracy: 0.9190 - val_loss: 2.3601 - val_accuracy: 0.5035
# Epoch 40/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.2075 - accuracy: 0.9236 - val_loss: 1.8634 - val_accuracy: 0.5174
# Epoch 41/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.2085 - accuracy: 0.9286 - val_loss: 3.1677 - val_accuracy: 0.3993
# Epoch 42/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.2052 - accuracy: 0.9271 - val_loss: 3.0890 - val_accuracy: 0.4549
# Epoch 43/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2202 - accuracy: 0.9205 - val_loss: 2.1882 - val_accuracy: 0.5278
# Epoch 44/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1943 - accuracy: 0.9344 - val_loss: 2.1268 - val_accuracy: 0.5174
# Epoch 45/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.2038 - accuracy: 0.9198 - val_loss: 1.8363 - val_accuracy: 0.5625
# Epoch 46/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1745 - accuracy: 0.9383 - val_loss: 1.9765 - val_accuracy: 0.5451
# Epoch 47/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1850 - accuracy: 0.9379 - val_loss: 2.5821 - val_accuracy: 0.4896
# Epoch 48/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1707 - accuracy: 0.9383 - val_loss: 1.8035 - val_accuracy: 0.5972
# Epoch 49/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1867 - accuracy: 0.9313 - val_loss: 2.2087 - val_accuracy: 0.5139
# Epoch 50/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1685 - accuracy: 0.9344 - val_loss: 2.8704 - val_accuracy: 0.4479
# Epoch 51/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.1636 - accuracy: 0.9417 - val_loss: 2.1344 - val_accuracy: 0.5625
# Epoch 52/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1546 - accuracy: 0.9464 - val_loss: 2.5377 - val_accuracy: 0.5000
# Epoch 53/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1557 - accuracy: 0.9483 - val_loss: 2.5347 - val_accuracy: 0.4965
# Epoch 54/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1493 - accuracy: 0.9464 - val_loss: 1.6181 - val_accuracy: 0.6111
# Epoch 55/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1582 - accuracy: 0.9433 - val_loss: 2.8224 - val_accuracy: 0.4896
# Epoch 56/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1404 - accuracy: 0.9525 - val_loss: 2.3032 - val_accuracy: 0.5312
# Epoch 57/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1409 - accuracy: 0.9522 - val_loss: 2.9077 - val_accuracy: 0.4861
# Epoch 58/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.1405 - accuracy: 0.9491 - val_loss: 2.0915 - val_accuracy: 0.5694
# Epoch 59/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1379 - accuracy: 0.9495 - val_loss: 2.2161 - val_accuracy: 0.5312
# Epoch 60/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1140 - accuracy: 0.9649 - val_loss: 2.0206 - val_accuracy: 0.5660
# Epoch 61/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1172 - accuracy: 0.9591 - val_loss: 1.8870 - val_accuracy: 0.5938
# Epoch 62/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1141 - accuracy: 0.9606 - val_loss: 2.4462 - val_accuracy: 0.5174
# Epoch 63/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1244 - accuracy: 0.9568 - val_loss: 2.4009 - val_accuracy: 0.5556
# Epoch 64/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1118 - accuracy: 0.9626 - val_loss: 4.4515 - val_accuracy: 0.4306
# Epoch 65/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1206 - accuracy: 0.9595 - val_loss: 3.3897 - val_accuracy: 0.4479
# Epoch 66/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1289 - accuracy: 0.9541 - val_loss: 4.1793 - val_accuracy: 0.4306
# Epoch 67/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1190 - accuracy: 0.9614 - val_loss: 4.1172 - val_accuracy: 0.4583
# Epoch 68/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.1046 - accuracy: 0.9660 - val_loss: 3.0187 - val_accuracy: 0.4653
# Epoch 69/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1250 - accuracy: 0.9560 - val_loss: 3.3609 - val_accuracy: 0.4618
# Epoch 70/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.1098 - accuracy: 0.9626 - val_loss: 2.1713 - val_accuracy: 0.5694
# Epoch 71/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1141 - accuracy: 0.9641 - val_loss: 3.0125 - val_accuracy: 0.5278
# Epoch 72/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1203 - accuracy: 0.9610 - val_loss: 3.6175 - val_accuracy: 0.4722
# Epoch 73/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1073 - accuracy: 0.9622 - val_loss: 3.6523 - val_accuracy: 0.4514
# Epoch 74/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0889 - accuracy: 0.9715 - val_loss: 3.1356 - val_accuracy: 0.5035
# Epoch 75/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.1058 - accuracy: 0.9657 - val_loss: 5.0184 - val_accuracy: 0.4201
# Epoch 76/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.1063 - accuracy: 0.9672 - val_loss: 2.3484 - val_accuracy: 0.5590
# Epoch 77/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.1039 - accuracy: 0.9630 - val_loss: 2.9380 - val_accuracy: 0.5312
# Epoch 78/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0846 - accuracy: 0.9722 - val_loss: 3.1900 - val_accuracy: 0.5069
# Epoch 79/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0877 - accuracy: 0.9695 - val_loss: 3.4829 - val_accuracy: 0.4792
# Epoch 80/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0938 - accuracy: 0.9684 - val_loss: 2.2938 - val_accuracy: 0.5590
# Epoch 81/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0992 - accuracy: 0.9653 - val_loss: 3.3801 - val_accuracy: 0.4757
# Epoch 82/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0834 - accuracy: 0.9715 - val_loss: 3.4277 - val_accuracy: 0.4826
# Epoch 83/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0762 - accuracy: 0.9745 - val_loss: 3.4839 - val_accuracy: 0.5104
# Epoch 84/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0826 - accuracy: 0.9703 - val_loss: 3.2219 - val_accuracy: 0.5035
# Epoch 85/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0934 - accuracy: 0.9707 - val_loss: 2.6081 - val_accuracy: 0.5347
# Epoch 86/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0727 - accuracy: 0.9715 - val_loss: 2.6398 - val_accuracy: 0.5451
# Epoch 87/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0730 - accuracy: 0.9730 - val_loss: 2.7531 - val_accuracy: 0.5486
# Epoch 88/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0737 - accuracy: 0.9742 - val_loss: 2.8681 - val_accuracy: 0.5556
# Epoch 89/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0673 - accuracy: 0.9761 - val_loss: 2.5677 - val_accuracy: 0.5104
# Epoch 90/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0895 - accuracy: 0.9695 - val_loss: 3.8107 - val_accuracy: 0.4722
# Epoch 91/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0934 - accuracy: 0.9672 - val_loss: 3.0767 - val_accuracy: 0.5278
# Epoch 92/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0926 - accuracy: 0.9691 - val_loss: 2.3423 - val_accuracy: 0.5451
# Epoch 93/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0969 - accuracy: 0.9645 - val_loss: 4.5374 - val_accuracy: 0.4583
# Epoch 94/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0771 - accuracy: 0.9753 - val_loss: 3.7293 - val_accuracy: 0.5139
# Epoch 95/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0734 - accuracy: 0.9772 - val_loss: 3.7545 - val_accuracy: 0.4931
# Epoch 96/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0739 - accuracy: 0.9753 - val_loss: 4.3395 - val_accuracy: 0.4826
# Epoch 97/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0750 - accuracy: 0.9788 - val_loss: 2.9650 - val_accuracy: 0.5382
# Epoch 98/1500
# 41/41 [==============================] - 3s 75ms/step - loss: 0.0801 - accuracy: 0.9722 - val_loss: 3.4126 - val_accuracy: 0.5451
# Epoch 99/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0762 - accuracy: 0.9695 - val_loss: 4.0599 - val_accuracy: 0.4549
# Epoch 100/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0870 - accuracy: 0.9688 - val_loss: 2.2889 - val_accuracy: 0.5729
# Epoch 101/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0954 - accuracy: 0.9691 - val_loss: 2.9391 - val_accuracy: 0.5208
# Epoch 102/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0896 - accuracy: 0.9684 - val_loss: 2.8920 - val_accuracy: 0.5243
# Epoch 103/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0753 - accuracy: 0.9742 - val_loss: 4.5993 - val_accuracy: 0.4479
# Epoch 104/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0788 - accuracy: 0.9699 - val_loss: 3.4303 - val_accuracy: 0.5243
# Epoch 105/1500
# 41/41 [==============================] - 3s 70ms/step - loss: 0.0720 - accuracy: 0.9753 - val_loss: 3.6020 - val_accuracy: 0.4826
# Epoch 106/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0653 - accuracy: 0.9780 - val_loss: 3.3224 - val_accuracy: 0.5069
# Epoch 107/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0715 - accuracy: 0.9761 - val_loss: 3.5012 - val_accuracy: 0.4931
# Epoch 108/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0736 - accuracy: 0.9718 - val_loss: 3.4642 - val_accuracy: 0.5069
# Epoch 109/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0545 - accuracy: 0.9823 - val_loss: 3.1590 - val_accuracy: 0.5312
# Epoch 110/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0509 - accuracy: 0.9823 - val_loss: 2.8248 - val_accuracy: 0.5347
# Epoch 111/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0474 - accuracy: 0.9830 - val_loss: 3.5608 - val_accuracy: 0.5139
# Epoch 112/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0548 - accuracy: 0.9811 - val_loss: 4.0589 - val_accuracy: 0.4965
# Epoch 113/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0551 - accuracy: 0.9819 - val_loss: 3.5413 - val_accuracy: 0.5243
# Epoch 114/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0581 - accuracy: 0.9799 - val_loss: 2.2510 - val_accuracy: 0.5799
# Epoch 115/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0577 - accuracy: 0.9792 - val_loss: 3.3469 - val_accuracy: 0.5278
# Epoch 116/1500
# 41/41 [==============================] - 3s 71ms/step - loss: 0.0488 - accuracy: 0.9811 - val_loss: 4.1599 - val_accuracy: 0.4792
# Epoch 117/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0570 - accuracy: 0.9803 - val_loss: 4.1348 - val_accuracy: 0.5069
# Epoch 118/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0709 - accuracy: 0.9753 - val_loss: 3.8877 - val_accuracy: 0.4792
# Epoch 119/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0574 - accuracy: 0.9815 - val_loss: 3.3168 - val_accuracy: 0.5347
# Epoch 120/1500
# 41/41 [==============================] - 3s 72ms/step - loss: 0.0636 - accuracy: 0.9765 - val_loss: 2.6513 - val_accuracy: 0.5417
# Epoch 121/1500
# 41/41 [==============================] - 3s 74ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 2.4993 - val_accuracy: 0.5799
# Epoch 122/1500
# 41/41 [==============================] - 3s 73ms/step - loss: 0.0543 - accuracy: 0.9803 - val_loss: 3.9104 - val_accuracy: 0.5208
# Epoch 123/1500
# 11/41 [=======>......................] - ETA: 2s - loss: 0.0478 - accuracy: 0.9844
